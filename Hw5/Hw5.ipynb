# %%
# 1. Клонируем официальный репозиторий
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix
# %cd pytorch-CycleGAN-and-pix2pix

# 2. Устанавливаем дополнительные библиотеки, необходимые для работы кода
# !pip install dominate wandb
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2619, done.
# remote: Total 2619 (delta 0), reused 0 (delta 0), pack-reused 2619 (from 1)
# Receiving objects: 100% (2619/2619), 8.24 MiB | 24.52 MiB/s, done.
# Resolving deltas: 100% (1654/1654), done.
# /content/pytorch-CycleGAN-and-pix2pix
# ...

# %%
import os

# Проверяем, где мы находимся, и заходим в правильную папку
if not os.path.exists('scripts/download_cyclegan_model.sh'):
    if os.path.exists('pytorch-CycleGAN-and-pix2pix'):
        # %cd pytorch-CycleGAN-and-pix2pix
    else:
        # Если папки вообще нет, клонируем заново
        # !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix.git
        # %cd pytorch-CycleGAN-and-pix2pix

# Запускаем скачивание модели заново
# !bash ./scripts/download_cyclegan_model.sh style_ukiyoe
# Out:
# Cloning into 'pytorch-CycleGAN-and-pix2pix'...
# remote: Enumerating objects: 2619, done.
# remote: Total 2619 (delta 0), reused 0 (delta 0), pack-reused 2619 (from 1)
# Receiving objects: 100% (2619/2619), 8.24 MiB | 31.47 MiB/s, done.
# Resolving deltas: 100% (1654/1654), done.
# /content/pytorch-CycleGAN-and-pix2pix
# Note: available models are apple2orange, orange2apple, summer2winter_yosemite, winter2summer_yosemite, horse2zebra, zebra2horse, monet2photo, style_monet, style_cezanne, style_ukiyoe, style_vangogh, sat2map, map2sat, cityscapes_photo2label, cityscapes_label2photo, facades_photo2label, facades_label2photo, iphone2dslr_flower
# Specified [style_ukiyoe]
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2026-07-20 05:59:40--  http://efrosgans.eecs.berkeley.edu/cyclegan/pretrained_models/style_ukiyoe.pth
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.244.190
# ...

# %%
import os
from google.colab import files

# Создаем структуру папок для инференса
os.makedirs('datasets/my_photo/testA', exist_ok=True)

# Загружаем изображение
uploaded = files.upload()

# Перемещаем загруженное фото в нужную директорию
for filename in uploaded.keys():
    os.rename(filename, os.path.join('datasets/my_photo/testA', filename))
    print(f'Файл {filename} успешно загружен и готов к обработке!')
# Out:
#      <input type="file" id="files-7ddd35d7-4589-4400-a4aa-90f179cbe1d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ddd35d7-4589-4400-a4aa-90f179cbe1d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install dominate
# !pip install wandb

# %%
# Запуск теста для одного изображения
# !python test.py --dataroot datasets/my_photo/testA --name style_ukiyoe_pretrained --model test --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/my_photo/testA       	[default: None]
#              dataset_mode: single
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: test
#              model_suffix:
#                n_layers_D: 3
#                      name: style_ukiyoe_pretrained       	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
# ...
